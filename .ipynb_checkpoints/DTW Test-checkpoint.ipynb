# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import os
import sys
import hdf5_getters
import numpy as np
from dtw import dtw
from numpy.linalg import norm

# %%
def norm2(x, y):
    return norm(x - y, ord=2)

def get_song_info(h5):
    print '%s - %s (%s) - %s bpm' % (hdf5_getters.get_artist_name(h5), hdf5_getters.get_title(h5), hdf5_getters.get_year(h5), hdf5_getters.get_tempo(h5))

# %%
h5list = []
folder = './data/B/F/R/'

for f in os.listdir(folder):
    h5list.append(hdf5_getters.open_h5_file_read(folder+f))

# %%
x = hdf5_getters.get_segments_timbre(h5list[0])
y = hdf5_getters.get_segments_timbre(h5list[1])
get_song_info(h5list[0])
get_song_info(h5list[1])
# Out:
# Less Than Jake - Automatic (1996) - 133.05 bpm
# Anti-Flag - I Don't Wanna be a War Hero (2003) - 106.065 bpm

# %%
dist, cost, path = dtw(x, y, dist=norm2)
print 'Minimum distance:', dist
# Out:
# Minimum distance: 55.2526041912

# %%
plt.plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x105ba8050>,
#  <matplotlib.lines.Line2D at 0x105ba8ad0>,
#  <matplotlib.lines.Line2D at 0x105ba8d10>,
#  <matplotlib.lines.Line2D at 0x105ba8ed0>,
#  <matplotlib.lines.Line2D at 0x104abf0d0>,
#  <matplotlib.lines.Line2D at 0x104abf290>,
#  <matplotlib.lines.Line2D at 0x104abf450>,
#  <matplotlib.lines.Line2D at 0x104bda410>,
#  <matplotlib.lines.Line2D at 0x104abf7d0>,
#  <matplotlib.lines.Line2D at 0x104abf990>,
#  <matplotlib.lines.Line2D at 0x104abfb50>,
#  <matplotlib.lines.Line2D at 0x104abfd10>]

# %%
plt.plot(y)
# Out:
# [<matplotlib.lines.Line2D at 0x105c00850>,
#  <matplotlib.lines.Line2D at 0x105c00ad0>,
#  <matplotlib.lines.Line2D at 0x105c00d10>,
#  <matplotlib.lines.Line2D at 0x105c00ed0>,
#  <matplotlib.lines.Line2D at 0x105c0b0d0>,
#  <matplotlib.lines.Line2D at 0x105c0b290>,
#  <matplotlib.lines.Line2D at 0x105c0b450>,
#  <matplotlib.lines.Line2D at 0x105b61bd0>,
#  <matplotlib.lines.Line2D at 0x105c0b7d0>,
#  <matplotlib.lines.Line2D at 0x105c0b990>,
#  <matplotlib.lines.Line2D at 0x105c0bb50>,
#  <matplotlib.lines.Line2D at 0x105c0bd10>]

# %%
plt.imshow(cost.T, origin='lower', cmap=matplotlib.cm.gray, interpolation='nearest')
plt.plot(path[0], path[1], 'w')
plt.xlim((-0.5, cost.shape[0]-0.5))
plt.ylim((-0.5, cost.shape[1]-0.5))
# Out:
# (-0.5, 345.5)
